# %% [markdown]
# # **Accessing Open source LLMs for Text Generation, Summarization and Chat Completion**

# %% [markdown]
# ### **What are Large Language Models (LLMs)?**
#
# LLMs (Large Language Models) are a type of artificial intelligence model designed to understand and generate human-like text. They are trained on massive datasets consisting of text from books, websites, articles, code, and other sources.
#
# > **Analogy**: *Think of an LLM as a super-smart autocomplete that doesn’t just finish your sentences, but can answer questions, write stories, code, and hold a conversation — like having an AI-powered assistant always ready!*
#
# **Key Features of LLMs:**
#
# - **Large** refers to the number of parameters (often billions or even trillions) used in the model.
#
# - **Language** refers to natural human language like English, Hindi, or even programming languages like Python.
#
# - **Model** means a mathematical system trained to predict and generate text.
#
# **What LLMs Can Do:**
#
# - Answer questions
#
# - Translate languages
#
# - Write essays, summaries, or poems
#
# - Generate code
#
# - Perform sentiment analysis
#
# - Extract information from documents
#
# - Power chatbots and virtual assistants

# %% [markdown]
# ## **Some of the LLM Uses We Perform in This Lab**
#
# 1. **Text Generation:**
# LLMs can create new text based on a prompt you provide.
#
#  Example: If you ask the model, “Write a short story about space,” it will generate a story based on that prompt.
#
# 2. **Summarization:**
# LLMs can shorten long texts while keeping the main points.
#
#   There are two types:
#
#  **Extractive Summarization:** Picks important sentences directly from the text.
#
#  **Abstractive Summarization:** Paraphrases and rewords the content to make it shorter.
#
#  Example: It can summarize long articles or reports into short, easy-to-read versions.
#
# 3. **Chat Completion:**
#  LLMs can carry on conversations, answering questions or chatting based on the context.
#
#  Example: If you ask, “What’s the weather like today?” it can generate a relevant response based on the question.
#
#
# ## **Open-Source LLMs:**
# There are open-source LLMs that you can use for these tasks:
#
# **1. tiiuae/falcon-7b-instruct (from Hugging Face):**
#
# - Falcon-7B is an instruction-tuned model, meaning it is optimized for responding to specific prompts or commands.
#
# - Hugging Face provides a lot of support for these types of models, making it easy to deploy and fine-tune for various tasks.
#
# - Capabilities: It can handle text generation, summarization, and provide answers based on instructions you give it.
#
# - Use Cases: Great for building conversational agents, providing answers, or generating content with specific guidelines.
#
# **2. deepseek-ai/DeepSeek-V3-0324 (from Hugging Face):**
#
# - DeepSeek V3 is part of a specialized model for information retrieval and search.
#
# - It excels in tasks that require contextual understanding and retrieval-augmented generation (RAG), which is useful for querying databases or documents.
#
# - Capabilities: It can generate text, summarize content, and assist in search-based tasks.
#
# - Use Cases: Best for building systems that need to search and retrieve relevant information from large datasets or documents.
#
# **3. llama3-8b-8192 (from Groq):**
# - Llama 3-8B is a powerful language model developed by Groq, optimized for high performance on large-scale tasks.
#
# - With 8 billion parameters, this model can handle large text inputs, making it great for complex text generation tasks and long-form content.
#
# - Capabilities: It can process large amounts of data and is suitable for text generation, summarization, and chat-based interactions.
#
# - Use Cases: Ideal for more resource-intensive applications, such as generating detailed content or handling conversations with a lot of context.
#
# ## 📊 Model Comparison
#
# Before trying the models, here’s a quick snapshot:
#
# | Model           | Size   | Ideal Tasks          | Strength           | Platform      |
# |-----------------|--------|---------------------|--------------------|--------------|
# | **Falcon-7B**   | 7B     | Text generation, summarization | General NLP tasks | Hugging Face |
# | **DeepSeek-V3** | V3     | Info retrieval, RAG | Search-centric, context-aware | Hugging Face |
# | **Llama3-8B**   | 8B     | Long conversations  | Handles long context | Groq |
#
# This will help you choose models for different tasks during exercises.

# %% [markdown]
# ## **Lab Execution**

# %% [markdown]
# ### **Prerequisites:**
# - [Create API Keys for Hugging Face & Groq LLM.](https://https://www.skool.com/k21academy/classroom/0a7dc03d?md=35ab1858bac04486b66a32547d6da30f)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **A. Using Hugging Face Transformers**
#
# This example shows how to run an open-source large language model (LLM) called Falcon-7B locally on your own machine using Hugging Face's Transformers library and PyTorch. The goal is to generate text based on an input prompt.

# %% [markdown]
# 1. Install Dependencies
#
#  ```transformers:``` This library provides pre-trained models for various NLP tasks such as text generation, summarization, question answering, etc. It also offers easy-to-use APIs for fine-tuning models.
#
#  ```torch:``` PyTorch is a deep learning framework that is widely used for building and training machine learning models, especially neural networks. It’s required by many NLP models, including those in the transformers library, for efficient computation and model inference.

# %%
# Install the 'transformers' library from Hugging Face, which provides access to a wide range of pre-trained models
# !pip install transformers

# Install 'torch' (PyTorch), a deep learning framework used for training and running neural network models
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# 2. Text Generation with falcon-7b-instruct via Hugging Face

# %%
# Import necessary libraries from the 'transformers' library
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# Load tokenizer and model (specifying the open-access Falcon 7B instruction model for this demo)
model_name = "tiiuae/falcon-7b-instruct"  # The model used for text generation tasks

# Load the tokenizer for the model; tokenizers convert input text into token IDs
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load the pre-trained model; it will be used for causal language modeling (text generation)
# The 'torch_dtype' is set to 'auto' to automatically choose the appropriate precision for the model
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype="auto")

# Create a text generation pipeline using the loaded model and tokenizer
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Define a prompt for text generation
prompt = "Explain the difference between AI and Machine Learning."

# Generate text based on the input prompt, limiting the response to a maximum of 100 new tokens
result = pipe(prompt, max_new_tokens=100)

# Print the generated text, which will be the model's response to the prompt
print(result[0]["generated_text"])
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Explain the difference between AI and Machine Learning.
# ...

# %% [markdown]
#  *Expected Response:*
#
#  The model will generate a clear and concise explanation, stating that AI is a broad field where machines perform tasks requiring human-like intelligence, while Machine Learning (ML) is a subset of AI focused on using data and algorithms to improve performance over time.

# %% [markdown]
# *Code Explanation*
#
# - ```AutoTokenizer.from_pretrained(model_name):``` Loads the tokenizer associated with the chosen pre-trained model, which is responsible for converting text into tokens (numeric representations).
#
# - ```AutoModelForCausalLM.from_pretrained(model_name, torch_dtype="auto"):``` Loads the model itself. CausalLM stands for Causal Language Modeling, which is used for tasks like text generation. The torch_dtype="auto" argument ensures that the model uses an appropriate data type for better performance.
#
# - ```pipeline("text-generation", model=model, tokenizer=tokenizer):``` Creates a pipeline for text generation. A pipeline is an easy-to-use wrapper that simplifies the process of applying a model to a task like text generation.
#
# - ```pipe(prompt, max_new_tokens=100):``` Generates text based on the given prompt. The max_new_tokens=100 limits the generated text to 100 tokens beyond the original prompt.
#
# - ```print(result[0]["generated_text"]):``` Prints the model's generated response. The result is a list, and we extract the generated text from the first item (result[0]) in the list.

# %% [markdown]
# ### **B. Using Hugging Face Inference API (Cloud-Based Inference)**
# This example uses Hugging Face's hosted inference API instead of running the model locally. This is useful if your machine can't handle large models or you want to avoid the setup complexity.

# %% [markdown]
# 1. Install ```huggingface_hub``` package:
#
#  It Allows interaction with Hugging Face’s cloud services programmatically.

# %%
# !pip install huggingface_hub

# %% [markdown]
# 2. Chat completion using hugging face inference
#
# - **Note:** Replace the placeholder ```YOUR_API_KEY``` with your Hugging Face API key. If you haven't created one yet, check the Prerequisites section for how to do so.
#
# - ```client = InferenceClient(token="YOUR_API_KEY")```

# %%
# Import necessary libraries
import os
from huggingface_hub import InferenceClient  # This library helps interact with Hugging Face's API

# Replace 'YOUR_API_KEY' with your actual API key
client = InferenceClient(token="hf_bDPGqpoes********NAaMRInOIUsmlmqv")  # Initialize the API client with the provided token

# Make a chat completion request using the DeepSeek V3 model
completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-V3-0324",  # Specify the model to use (DeepSeek V3 for this example)
    messages=[  # Provide a list of messages for the model to process
        {
            "role": "user",  # Define the sender's role (in this case, the user)
            "content": "Explain LLM in simple terms."  # The actual prompt/message the user asks
        }
    ],
)

# Print the response generated by the model
print(completion.choices[0].message)  # Extract and print the model's response to the prompt
# Out:
# ChatCompletionOutputMessage(role='assistant', content='Sure! Let’s break down **LLM (Large Language Model)** in simple terms.  \n\n### What is an LLM?  \nAn **LLM** is a very advanced computer program that understands and generates human-like text. It’s trained on **massive amounts of text data** (books, articles, websites, etc.) to recognize patterns and predict the next word in a sentence.  \n\n### How does it work?  \n1. **"Learns" from huge amounts of text** → By analyzing billions of sentences, it figures out grammar, facts, and even nuance.  \n2. **Predicts the next word** → If you type, _"The sky is..."_ it guesses _"blue"_ based on patterns it has seen before.  \n3. **Generates coherent responses** → It can answer questions, write essays, or even code by breaking down context.  \n\n### Example:  \nIf you ask, *"Why is the sky blue?"*, the LLM doesn’t *"know"* like a human, but it predicts an answer based on patterns from science articles it was trained on.  \n\n### Key Featur
# ...

# %% [markdown]
# *Code Explanation:*
# - ```InferenceClient(token="your_api_key"):``` Initializes the Hugging Face API client using your personal API key.
#
# - ```client.chat.completions.create(...):``` This sends the user's message to the DeepSeek V3 model and asks it to generate a response.
#
# - ```model="deepseek-ai/DeepSeek-V3-0324":``` Specifies the model you're using for the task (in this case, DeepSeek V3).
#
# - ```messages=[...]:``` The list of messages contains the input from the user (in this case, asking for a simple explanation of LLM).
#
# - ```print(completion.choices[0].message):``` Prints the model’s response from the API.
#
#  This code interacts with the Hugging Face API to generate a response from the specified model.

# %% [markdown]
# ### **C. Using Groq Cloud API (for Open LLMs)**
#
# This example demonstrates how to use Groq’s cloud inference service, a specialized platform optimized for very fast processing of large open-source models like Llama3.

# %% [markdown]
# - **Note:** Replace the placeholder ```YOUR_API_KEY``` with your Groq API key. If you haven't created one yet, check the Prerequisites section for how to do so.
#
# - ```api_key="YOUR_API_KEY"```

# %%
# Import necessary libraries
import os
from openai import OpenAI  # Importing the OpenAI package for interacting with the OpenAI API

# Initialize the OpenAI client with the provided API key and custom endpoint URL
client = OpenAI(
    api_key="gsk_xBtZaqqCmEs8z8knnF0******YB0c7UVqIfdlUWlYjA7YQKmop",  # Replace with your actual API key
    base_url="https://api.groq.com/openai/v1"   # Custom API endpoint (in this case, Groq’s endpoint)
)

# Make a chat completion request to the specified model
response = client.chat.completions.create(
    model="llama3-8b-8192",  # Specify the model you want to use (Llama-3 8B model in this case)
    messages=[  # The conversation history, with the user's input message
        {"role": "user", "content": "Summarize Retrieval Augmented Generation (RAG)."}  # User's question to summarize RAG
    ],
    max_tokens=150  # Limit the response to a maximum of 150 tokens
)

# Print the model's generated response (extracted from the first choice in the response)
print(response.choices[0].message.content)  # Extracts and prints the model's summary
# Out:
# Retrieval Augmented Generation (RAG) is a type of language model that combines the strengths of both retrieval-based and generation-based approaches for natural language processing tasks. In traditional language models, the model generates text from scratch, whereas in retrieval-based models, the model retrieves relevant text fragments and combines them to generate the output. RAG combines these two approaches by generating text based on what it has learned from a large corpus of text and retrieving relevant snippets from the same corpus to incorporate into the generated text.
#
# The key idea behind RAG is to utilize the strengths of both generation and retrieval to achieve better performance in several areas, such as:
#
# 1. **Improved coherence**: RAG allows the model to draw from a vast repository of text fragments,

# %% [markdown]
# *Code Explanation:*
#
# - ```OpenAI(api_key="your_api_key", base_url="custom_url"):``` Initializes the OpenAI client with your API key and a custom API endpoint. In your case, the endpoint is from Groq's API.
#
# - ```client.chat.completions.create(...):``` This sends a request to the API to generate a response based on the model (llama3-8b-8192). You are asking the model to summarize Retrieval Augmented Generation (RAG).
#
# - ```max_tokens=150:``` Limits the length of the generated response to 150 tokens.
#
# - ```print(response.choices[0].message.content):``` Extracts the first generated response (from choices[0]) and prints the content of the message.
#
# - This code interacts with the Groq API to generate a summary for the given prompt using the specified Llama-3 model.
